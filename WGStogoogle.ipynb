# %%
#所有代码

from __future__ import division
from math import pi,sqrt,sin,cos

# a python binding of https://on4wp7.codeplex.com/SourceControl/changeset/view/21483#353936

# Krasovsky 1940
#
# a = 6378245.0, 1/f = 298.3
# b = a * (1 - f)
# ee = (a^2 - b^2) / a^2
a = 6378245.0
ee = 0.00669342162296594323

# World Geodetic System ==> Mars Geodetic System
def transform(wgLat, wgLon):
    """
    transform(latitude,longitude) , WGS84
    return (latitude,longitude) , GCJ02
    """
    if (outOfChina(wgLat, wgLon)):
        mgLat = wgLat
        mgLon = wgLon
        return
    dLat = transformLat(wgLon - 105.0, wgLat - 35.0)
    dLon = transformLon(wgLon - 105.0, wgLat - 35.0)
    radLat = wgLat / 180.0 * pi
    magic = sin(radLat)
    magic = 1 - ee * magic * magic
    sqrtMagic = sqrt(magic)
    dLat = (dLat * 180.0) / ((a * (1 - ee)) / (magic * sqrtMagic) * pi)
    dLon = (dLon * 180.0) / (a / sqrtMagic * cos(radLat) * pi)
    mgLat = wgLat + dLat
    mgLon = wgLon + dLon
    return mgLat,mgLon

def outOfChina(lat, lon):
    if (lon < 72.004 or lon > 137.8347):
        return True
    if (lat < 0.8293 or lat > 55.8271):
        return True
    return False

def transformLat(x, y):
    ret = -100.0 + 2.0 * x + 3.0 * y + 0.2 * y * y + 0.1 * x * y + 0.2 * sqrt(abs(x))
    ret += (20.0 * sin(6.0 * x * pi) + 20.0 * sin(2.0 * x * pi)) * 2.0 / 3.0
    ret += (20.0 * sin(y * pi) + 40.0 * sin(y / 3.0 * pi)) * 2.0 / 3.0
    ret += (160.0 * sin(y / 12.0 * pi) + 320 * sin(y * pi / 30.0)) * 2.0 / 3.0
    return ret

def transformLon(x, y):
    ret = 300.0 + x + 2.0 * y + 0.1 * x * x + 0.1 * x * y + 0.1 * sqrt(abs(x))
    ret += (20.0 * sin(6.0 * x * pi) + 20.0 * sin(2.0 * x * pi)) * 2.0 / 3.0
    ret += (20.0 * sin(x * pi) + 40.0 * sin(x / 3.0 * pi)) * 2.0 / 3.0
    ret += (150.0 * sin(x / 12.0 * pi) + 300.0 * sin(x / 30.0 * pi)) * 2.0 / 3.0
    return ret

if __name__ == "__main__":
    WGS84_Lat = 39.990205
    WGS84_Long = 116.327847
    print (transform(WGS84_Lat,WGS84_Long))
# Out:
# (39.991519388614314, 116.3339908951279)

# %%
import pandas as pd

# %%
data=pd.read_excel("Schooldata_cleaned.xlsx")

# %%
data.head()
# Out:
#                     name            address  district assignmode  \
# 0           北京市陈经纶中学嘉铭分校       北京市朝阳区北苑路86号  Chaoyang  Nineyears
# 1             北京市十一学校一分校  北京市海淀区万寿路街道翠微路19号   Haidian  Nineyears
# 2                北京市育鸿学校       北京市海淀区复兴路14号   Haidian  Nineyears
# 3  中国教育科学研究院朝阳实验学校(中学校部)   北京市朝阳区安贞西里一区13号楼  Chaoyang  Nineyears
# 4           北京市海淀区崛起实验学校     北京市海淀区菊园小区11号楼   Haidian  Nineyears
#
#   primaryormiddle  quality  Unnamed: 6   WGS84lat    WGS84lon
# 0         primary        3         NaN  40.001021  116.417500
# 1         primary        4         NaN  39.898893  116.278256
# 2         primary        4         NaN  39.897561  116.307324
# 3         primary        5         NaN  39.972325  116.392909
# 4         primary        5         NaN  40.032232  116.281552

# %%
transform(40.001021, 116.417500)[0]
# Out:
# 40.002423844038546

# %%
data["glat"]=1
data["glon"]=1
data.shape
# Out:
# (734, 11)

# %%
for i in range(0,len(data),1):
    
    lat1=data.iloc[i,7]
    lat1=float(lat1)
    lon1=data.iloc[i,8]
    lon1=float(lon1)
    #所有代码

    

# a python binding of https://on4wp7.codeplex.com/SourceControl/changeset/view/21483#353936

# Krasovsky 1940
#
# a = 6378245.0, 1/f = 298.3
# b = a * (1 - f)
# ee = (a^2 - b^2) / a^2
    a = 6378245.0
    ee = 0.00669342162296594323

# World Geodetic System ==> Mars Geodetic System
    def transform(wgLat, wgLon):
        if (outOfChina(wgLat, wgLon)):
            mgLat = wgLat
            mgLon = wgLon
            return
        dLat = transformLat(wgLon - 105.0, wgLat - 35.0)
        dLon = transformLon(wgLon - 105.0, wgLat - 35.0)
        radLat = wgLat / 180.0 * pi
        magic = sin(radLat)
        magic = 1 - ee * magic * magic
        sqrtMagic = sqrt(magic)
        dLat = (dLat * 180.0) / ((a * (1 - ee)) / (magic * sqrtMagic) * pi)
        dLon = (dLon * 180.0) / (a / sqrtMagic * cos(radLat) * pi)
        mgLat = wgLat + dLat
        mgLon = wgLon + dLon
        return mgLat,mgLon

    def outOfChina(lat, lon):
        if (lon < 72.004 or lon > 137.8347):
            return True
        if (lat < 0.8293 or lat > 55.8271):
            return True
        return False

    def transformLat(x, y):
        ret = -100.0 + 2.0 * x + 3.0 * y + 0.2 * y * y + 0.1 * x * y + 0.2 * sqrt(abs(x))
        ret += (20.0 * sin(6.0 * x * pi) + 20.0 * sin(2.0 * x * pi)) * 2.0 / 3.0
        ret += (20.0 * sin(y * pi) + 40.0 * sin(y / 3.0 * pi)) * 2.0 / 3.0
        ret += (160.0 * sin(y / 12.0 * pi) + 320 * sin(y * pi / 30.0)) * 2.0 / 3.0
        return ret

    def transformLon(x, y):
        ret = 300.0 + x + 2.0 * y + 0.1 * x * x + 0.1 * x * y + 0.1 * sqrt(abs(x))
        ret += (20.0 * sin(6.0 * x * pi) + 20.0 * sin(2.0 * x * pi)) * 2.0 / 3.0
        ret += (20.0 * sin(x * pi) + 40.0 * sin(x / 3.0 * pi)) * 2.0 / 3.0
        ret += (150.0 * sin(x / 12.0 * pi) + 300.0 * sin(x / 30.0 * pi)) * 2.0 / 3.0
        return ret

    if __name__ == "__main__":
        WGS84_Lat = 39.990205
        WGS84_Long = 116.327847
    
    
    wj=transform(lat1,lon1)
    try:
        data.iloc[i,9]=wj[0]
        data.iloc[i,10]=wj[1]
    except:
        data.iloc[i,9]=0
        data.iloc[i,10]=0
        print(i)
# Out:
# 71
# 545

# %%
data
# Out:
#                       name                  address   district assignmode  \
# 0             北京市陈经纶中学嘉铭分校             北京市朝阳区北苑路86号   Chaoyang  Nineyears
# 1               北京市十一学校一分校        北京市海淀区万寿路街道翠微路19号    Haidian  Nineyears
# 2                  北京市育鸿学校             北京市海淀区复兴路14号    Haidian  Nineyears
# 3    中国教育科学研究院朝阳实验学校(中学校部)         北京市朝阳区安贞西里一区13号楼   Chaoyang  Nineyears
# 4             北京市海淀区崛起实验学校           北京市海淀区菊园小区11号楼    Haidian  Nineyears
# 5            北京市海淀北部新区实验学校           北京市海淀区苏家坨镇西小营村    Haidian  Nineyears
# 6                北京市中科启元学校          北京市海淀区中关村南三街10号    Haidian  Nineyears
# 7             首都师范大学附属玉泉学校               北京市海淀区闵庄南路    Haidian  Nineyears
# 8             首都师范大学附属玉泉学校               北京市海淀区闵庄南路    Haidian  Nineyears
# 9                北京市和平北路学校           北京市东城区安外大街168号  Dongcheng  Nineyears
# 10               北京市第一一五中学            北京市东城区天坛东路13号  Dongcheng  Nineyears
# 11     北京市正泽学校（新增） 非营利民办学校             北京市西城区丁章胡同1号    Xicheng  Nineyears
# ...

# %%
data.shape
# Out:
# (734, 11)

# %%
data1=pd.read_excel("translation_Schooldata_cleaned.xlsx")

# %%
data1.shape
# Out:
# (734, 9)

# %%
data.to_csv("google_crs2.csv",encoding="utf_8_sig")

# %%
# import the SQLAlchemy libraries
from sqlalchemy import create_engine

# create the connection string to the MySQL database
# replace USERNAME and PASSWORD with your own credentials 
engine = create_engine('mysql+pymysql://ucfnjwa:yapisodexe@dev.spatialdatacapture.org:3306/ucfnjwa?charset=utf8"')

# make the connection to the database
conn = engine.raw_connection()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-8cca8846599f> in <module>()
#       4 # create the connection string to the MySQL database
#       5 # replace USERNAME and PASSWORD with your own credentials
# ----> 6 engine = create_engine('mysql+pymysql://ucfnjwa:yapisodexe@dev.spatialdatacapture.org:3306/ucfnjwa?charset=utf8"')
#       7
#       8 # make the connection to the database
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     385     strategy = kwargs.pop('strategy', default_strategy)
#     386     strategy = strategies.strategies[strategy]
# --> 387     return strategy.create(*args, **kwargs)
#     388
#     389
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      78                 if k in kwargs:
# ...
