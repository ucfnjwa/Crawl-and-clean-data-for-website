# %%
import pandas as pd

# %%
data=pd.read_csv("Housing Price Data_haidian.csv")

# %%
data.head()
# Out:
#    schooldistrict_bestmiddle_dist  district_bestmiddle_dist  \
# 0                     1937.178928               9887.533315
# 1                     1639.671292               9610.093065
# 2                     1600.123433               9501.001408
# 3                     1500.588269               9469.146369
# 4                     1039.831041               8721.752459
#
#    nearest_middle_distance    unitprice
# 0              1937.178928  75385.33333
# 1              1639.671292  64801.00000
# 2              1600.123433  62313.20000
# 3              1500.588269  76471.00000
# 4              1039.831041  64795.20000

# %%
c=len(data)

# %%
c
# Out:
# 375

# %%
www=[[3001.75756, 48813.75],[13307.90432, 48547.5]]

for i in range(0,len(data),1):
    lbbb=[data.iloc[i,1],data.iloc[i,3]]
    www.append(lbbb)  
www
# Out:
# [[3001.75756, 48813.75],
#  [13307.90432, 48547.5],
#  [9887.5333150000006, 75385.333329999994],
#  [9610.0930650000009, 64801.0],
#  [9501.0014080000001, 62313.199999999997],
#  [9469.146369, 76471.0],
#  [8721.7524590000012, 64795.199999999997],
#  [9486.4932339999996, 89778.5],
#  [8571.2591530000009, 76943.0],
#  [8575.8339649999998, 87251.0],
#  [8606.3078530000003, 71305.0],
#  [9026.8530229999997, 72920.0],
#  [8440.0626470000007, 78989.333329999994],
#  [8356.5205089999999, 79929.0],
#  [8313.1430920000003, 74342.333329999994],
#  [8263.8951959999995, 75238.399999999994],
#  [8223.6944220000005, 82555.0],
#  [8770.3176309999999, 61812.800000000003],
#  [8072.7533409999996, 75521.0],
#  [9299.0394419999993, 97472.0],
#  [8022.0668269999996, 79033.0],
#  [9401.2133510000003, 89981.0],
#  [7820.2586900000006, 87145.0],
#  [7829.6977340000003, 101822.5],
#  [9043.3278470000005, 95809.0],
#  [7812.4541829999998, 88413.333329999994],
#  [8965.787115000001, 98485.75],
# ...

# %%
thefile = open('1.txt', 'w')
thefile.write(www)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-45044b0d93f9> in <module>()
#       1 thefile = open('1.txt', 'w')
# ----> 2 thefile.write(www)
#
# TypeError: write() argument must be str, not list

# %%
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'limit_output':10000})
