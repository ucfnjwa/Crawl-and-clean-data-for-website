# %%
import requests 
import pandas as pd
import re
dataall=pd.DataFrame({"NAME" : ["1","1"] ,"number":["1","1"]})

# %%
encoding='utf_8_sig'

# %%
# -*-coding:utf8-*-

import requests

req = requests.get("http://www.eol.cn/html/zhongxue/bjzxx/#1")

if req.encoding == 'ISO-8859-1':
    encodings = requests.utils.get_encodings_from_content(req.text)
    if encodings:
        encoding = encodings[0]
    else:
        encoding = req.apparent_encoding

    # encode_content = req.content.decode(encoding, 'replace').encode('utf-8', 'replace')
    global encode_content
    encode_content = req.content.decode(encoding, 'replace') #如果设置为replace，则会用?取代非法字符；


print(encode_content)

with open('test.html','w',encoding='utf-8') as f:
    f.write(encode_content)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=gbk" />
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">
# 	<meta name="viewport" content="width=1000,user-scalable=no" />
# 	<meta name="format-detection" content="telephone=no">
# 	<title>北京基础教育（中小学）学校名单-中国教育在线</title>
# 	<meta name="keywords" content="北京小学名单,北京中学名单,北京中小学名单,中小学名单,北京义务教育学校名单,小学,初级中学,中学,完全中学,九年一贯制,十二年一贯制,高级中学" />
# 	<meta name="description" content="北京基础教育（中小学）学校名单专题，是中国教育在线独家策划并突出，主要内容包含北京市义务教育阶段小学、初中、高中学校的名单，并按照学校类型将中学分为初级中学、高级中学、九年一贯制、十二年一贯制、完全中学，希望对广大家长及学生有所帮助！" />
# 	<meta name="copyright" content="www.eol.cn" />
# 	<meta content="all" name="robots" />
# 	<base target="_blank" />
# 	<link rel="stylesheet" type="text/css" href="css/index.css" />
# </head>
# <body>
# <!-- 主要内容 -->
# <div class="header width1000">
# 	<img src="img/header.jpg"/>
# </div>
# <div class="container width1000">
# 	<div class="address width92">
# 		<ul>
# ...

# %%
encode_content
# Out:
# '<!DOCTYPE html>\r\n<html lang="zh-CN">\r\n<head>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=gbk" />\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">\r\n\t<meta name="viewport" content="width=1000,user-scalable=no" />\r\n\t<meta name="format-detection" content="telephone=no">\r\n\t<title>北京基础教育（中小学）学校名单-中国教育在线</title>\r\n\t<meta name="keywords" content="北京小学名单,北京中学名单,北京中小学名单,中小学名单,北京义务教育学校名单,小学,初级中学,中学,完全中学,九年一贯制,十二年一贯制,高级中学" />\r\n\t<meta name="description" content="北京基础教育（中小学）学校名单专题，是中国教育在线独家策划并突出，主要内容包含北京市义务教育阶段小学、初中、高中学校的名单，并按照学校类型将中学分为初级中学、高级中学、九年一贯制、十二年一贯制、完全中学，希望对广大家长及学生有所帮助！" />\r\n\t<meta name="copyright" content="www.eol.cn" />\r\n\t<meta content="all" name="robots" />\r\n\t<base target="_blank" />\r\n\t<link rel="stylesheet" type="text/css" href="css/index.css" />\r\n</head>\r\n<body>\r\n<!-- 主要内容 -->\r\n<div class="header width1000">\r\n\t<img src="img/header.jpg"/>\r\n</div>\r\n<div class="container width1000">\r\n\t<div class="
# ...

# %%
html=text.content
html_doc=html.decode("utf-8-sig","ignore")
print(html_doc)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=gbk" />
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">
# 	<meta name="viewport" content="width=1000,user-scalable=no" />
# 	<meta name="format-detection" content="telephone=no">
# 	<title>СѧѧУ-й</title>
# 	<meta name="keywords" content="Сѧ,ѧ,Сѧ,Сѧ,ѧУ,Сѧ,ѧ,ѧ,ȫѧ,һ,ʮһ,߼ѧ" />
# 	<meta name="description" content="СѧѧУר⣬й߶Ҳ߻ͻҪݰ׶СѧСѧУѧУͽѧΪѧ߼ѧһơʮһơȫѧϣԹҳѧ" />
# 	<meta name="copyright" content="www.eol.cn" />
# 	<meta content="all" name="robots" />
# 	<base target="_blank" />
# 	<link rel="stylesheet" type="text/css" href="css/index.css" />
# </head>
# <body>
# <!-- Ҫ -->
# <div class="header width1000">
# 	<img src="img/header.jpg"/>
# </div>
# <div class="container width1000">
# 	<div class="address width92">
# 		<ul>
# 			<li class="active"><a href="#1" target="_self"></a></li>
# 			<li><a href="#1" target="_self"></a></li>
# ...

# %%
text.encoding='utf-8'
print(text.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=gbk" />
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">
# 	<meta name="viewport" content="width=1000,user-scalable=no" />
# 	<meta name="format-detection" content="telephone=no">
# 	<title>����������������Сѧ��ѧУ����-�й���������</title>
# 	<meta name="keywords" content="����Сѧ����,������ѧ����,������Сѧ����,��Сѧ����,�����������ѧУ����,Сѧ,������ѧ,��ѧ,��ȫ��ѧ,����һ����,ʮ����һ����,�߼���ѧ" />
# 	<meta name="description" content="����������������Сѧ��ѧУ����ר�⣬���й��������߶��Ҳ߻���ͻ������Ҫ���ݰ�����������������׶�Сѧ�����С�����ѧУ��������������ѧУ���ͽ���ѧ��Ϊ������ѧ���߼���ѧ������һ���ơ�ʮ����һ���ơ���ȫ��ѧ��ϣ���Թ��ҳ���ѧ������������" />
# 	<meta name="copyright" content="www.eol.cn" />
# 	<meta content="all" name="robots" />
# 	<base target="_blank" />
# 	<link rel="stylesheet" type="text/css" href="css/index.css" />
# </head>
# <body>
# <!-- ��Ҫ���� -->
# ...

# %%
text=requests.get("http://www.eol.cn/html/zhongxue/bjzxx/#1")
pattern1 = re.compile(r'width="81">(.*?)</td>')
mytext1 = re.findall(pattern1,text.text)
mytext1
# Out:
# ['±±¾©ÊÐÎ÷³ÇÇø×ÔÖÒÐ¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇø¸®ÓÒ½Ö±û27ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøÁ¦Ñ§Ð¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøÁ¦Ñ§ºúÍ¬47ºÅ',
#  '±±¾©µÚÒ»ÊµÑéÐ¡Ñ§Ç°ÃÅ·ÖÐ£',
#  '±±¾©ÊÐÎ÷³ÇÇøºÍÆ½ÃÅÍâ¶«½Ö¼×5ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøÐÂÊÀ¼ÍÊµÑéÐ¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøÄÏÎ³Â·2ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøÏã³§Â·Ð¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøÏã³§Â·31ºÅ',
#  '±±¾©µÚÒ»ÊµÑéÐ¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøÄÏÐÂ»ª½Ö17ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøÌÕÈ»Í¤Ð¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøÁúÈªºúÍ¬5ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇø¸£ÖÝ¹ÝÐ¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇø¸£ÖÝ¹ÝÇ°½Ö3ºÅ',
#  '±±¾©Ð¡Ñ§×ß¶Á²¿',
#  '±±¾©ÊÐÎ÷³ÇÇø±±Ïß¸ó½Ö2ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇø¿µÀÖÀïÐ¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇø´¢¿âÓª¿µÀÖÀï2ºÅ',
#  '±±¾©Ð¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇø»±°ØÊ÷½Ö9ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøµÇÀ³Ð¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøµÇÀ³ºúÍ¬29ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇø±±³¤½ÖÐ¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇø±±³¤½Ö71ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøË³³Ç½ÖµÚÒ»Ð¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøÇ°ÃÅÎ÷´ó½Ö135ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøÁøÒñ½ÖÐ¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøÎ÷Ãº³§ºúÍ¬7ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøÊ²É²º£Ð¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇø¹§¼óºúÍ¬41ºÅ',
#  '±±¾©ÊÐÎ÷³ÇÇøÊµÑéÐ¡Ñ§',
#  '±±¾©ÊÐÎ÷³ÇÇøÄÏ²ËÔ°35ºÅ',
# ...

# %%
pattern1 = re.compile(r'>(.*?)</td>')
mytext1 = re.findall(pattern1,encode_content)

# %%
mytext1=pd.DataFrame(mytext1)

# %%
mytext1.shape
# Out:
# (3297, 1)

# %%
mytext1.to_csv("school1.csv",encoding="utf-8-sig")

# %%
data=pd.read_csv("school1.csv",encoding="utf-8-sig")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17387)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_decode (pandas\_libs\parsers.c:23510)()
#
# C:\Program Files\Anaconda3\lib\encodings\utf_8_sig.py in decode(input, errors)
#      22         prefix = 3
# ---> 23     (output, consumed) = codecs.utf_8_decode(input, errors, True)
#      24     return (output, consumed+prefix)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb7 in position 12: invalid start byte
#
# ...

# %%
data
# Out:
#       Unnamed: 0                        0
# 0              0              ???????????
# 1              1           ???????????14?
# 2              2            ?????????????
# 3              3        ??????????????20?
# 4              4             ????????????
# 5              5          ??????????119??
# 6              6               ??????????
# 7              7           ???????????60?
# 8              8             ????????????
# 9              9           ???????????14?
# 10            10           ??????????????
# 11            11         ??????????????7?
# 12            12             ????????????
# 13            13            ??????????31?
# 14            14             ????????????
# 15            15            ???????????1?
# 16            16              ???????????
# 17            17      ???????????????10??
# 18            18              ???????????
# 19            19           ???????????19?
# 20            20                ?????????
# ...
